# %% [markdown]
# # Mapping bike lanes in Pittsburgh
# As a cyclist who's primary source of transportation is a bicycle, I wanted to get a better understanding of

# %% [markdown]
# ## Setting up the notebook
# I cheated and wrote a wrapper for accessing Overpass API in a separate file - here is the link to the github gist and, which includes the API class and a quick function to calculate length from the lat/lon coords returned from the API.

# %%
import pandas as pd

# %%
bike_lanes = pd.read_json('bikes.json')

# %%
bike_lanes.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2850 entries, 0 to 2849
# Data columns (total 184 columns):
#  #    Column                                 Dtype
# ---   ------                                 -----
#  0    index                                  int64
#  1    type                                   object
#  2    id                                     int64
#  3    nodes                                  object
#  4    geometry                               object
#  5    bounds.minlat                          float64
#  6    bounds.minlon                          float64
#  7    bounds.maxlat                          float64
#  8    bounds.maxlon                          float64
#  9    tags.cycleway                          object
#  10   tags.highway                           object
#  11   tags.lcn                               object
#  12   tags.name                              object
#  13   tags.tiger:cfcc                        object
#  14   tags.tiger:name_base                   object
#  15   tags.tiger:name_direction_prefix       object
#  16   tags.tiger:name_type                   object
#  17   tags.tiger:zip_left                    object
#  18   tags.tiger:zip_right                   object
#  19   tags.bicycle                           object
#  20   tags.alt_name                          object
#  21   tags.source:alt_name                   object
#  22   tags.source:name                       object
#  23   tags.oneway                            object
#  24   tags.surface                           object
#  25   tags.tiger:reviewed                    object
#  26   tags.service                           object
#  27   tags.maxspeed                          object
#  28   tags.source:geometry                   object
#  29   tags.est_width                         object
#  30   tags.foot                              object
#  31   tags.note                              object
#  32   tags.access                            object
#  33   tags.source                            object
#  34   tags.source:cycleway                   object
#  35   tags.lanes                             float64
#  36   tags.lanes:backward                    float64
#  37   tags.lanes:forward                     float64
#  38   tags.lit                               object
#  39   tags.sidewalk                          object
#  40   tags.old_name                          object
#  41   tags.old_ref_legislative               object
#  42   tags.ref                               object
#  43   tags.ref:penndot                       object
#  44   tags.parking:lane:right                object
#  45   tags.NHS                               object
#  46   tags.incline                           object
#  47   tags.old_ref                           object
#  48   tags.maxspeed:forward                  object
#  49   tags.source:highway                    object
#  50   tags.turn:lanes:forward                object
#  51   tags.source:local_knowledge            object
#  52   tags.cycleway:left                     object
#  53   tags.hgv                               object
#  54   tags.maxspeed:type                     object
#  55   tags.horse                             object
#  56   tags.tiger:zip_left_1                  float64
#  57   tags.bridge                            object
#  58   tags.layer                             float64
#  59   tags.ref:nhrp                          float64
#  60   tags.wikipedia                         object
#  61   tags.source:sidewalk                   object
#  62   tags.motor_vehicle                     object
#  63   tags.tiger:zip_right_1                 float64
#  64   tags.sidewalk:right                    object
#  65   tags.source:lcn                        object
#  66   tags.maxweight                         object
#  67   tags.historic:railway                  object
#  68   tags.source:access                     object
#  69   tags.tiger:name_base_1                 object
#  70   tags.turn:lanes:backward               object
#  71   tags.maxlength                         object
#  72   tags.maxwidth                          object
#  73   tags.parking:lane:both                 object
#  74   tags.cycleway:right                    object
#  75   tags.destination:ref:to                object
#  76   tags.expressway                        object
#  77   tags.name_2                            object
#  78   tags.tiger:name_base_2                 object
#  79   tags.tiger:name_type_2                 object
#  80   tags.oneway:bicycle                    object
#  81   tags.lane_markings                     object
#  82   tags.bridge:name                       object
#  83   tags.maxgcweight                       float64
#  84   tags.parking:lane                      object
#  85   tags.source:geometry:date              object
#  86   tags.removed:highway                   object
#  87   tags.fixme                             object
#  88   tags.outdoor_seating                   object
#  89   tags.survey:date                       object
#  90   tags.parking:condition:both            object
#  91   tags.parking:condition:both:maxstay    object
#  92   tags.parking:condition:both:residents  object
#  93   tags.source:cycleway:left              object
#  94   tags.handrail                          object
#  95   tags.tiger:zip_left_2                  float64
#  96   tags.tiger:zip_left_3                  float64
#  97   tags.name_1                            object
#  98   tags.tiger:name_direction_prefix_1     object
#  99   tags.tiger:name_type_1                 object
#  100  tags.bridge:structure                  object
#  101  tags.source:bicycle                    object
#  102  tags.tracktype                         object
#  103  tags.trail_visibility                  object
#  104  tags.cycleway:right:oneway             object
#  105  tags.destination:ref                   object
#  106  tags.official_name                     object
#  107  tags.historic                          object
#  108  tags.ref:nrhp                          float64
#  109  tags.parking:lane:left                 object
#  110  tags.loc_name                          object
#  111  tags.old_railway_operator              object
#  112  tags.railway                           object
#  113  tags.operator                          object
#  114  tags.cycleway:left:oneway              object
#  115  tags.destination                       object
#  116  tags.maxspeed:advisory                 object
#  117  tags.segregated                        object
#  118  tags.source:lanes                      object
#  119  tags.history                           object
#  120  tags.source:bridge                     object
#  121  tags.abandoned:railway                 object
#  122  tags.embedded_rails                    object
#  123  tags.description                       object
#  124  tags.hov                               object
#  125  tags.noref                             object
#  126  tags.maxweight:note                    object
#  127  tags.check_date                        object
#  128  tags.construction                      object
#  129  tags.change:lanes                      object
#  130  tags.turn:lanes                        object
#  131  tags.reg_name                          object
#  132  tags.destination:lanes                 object
#  133  tags.destination:ref:lanes             object
#  134  tags.destination:ref:to:lanes          object
#  135  tags.turn                              object
#  136  tags.note:maxweight                    object
#  137  tags.maxweight:combinations            object
#  138  tags.network                           object
#  139  tags.crossing                          object
#  140  tags.footway                           object
#  141  tags.addr:city                         object
#  142  tags.addr:street                       object
#  143  tags.junction                          object
#  144  tags.source:footway                    object
#  145  tags.demolished:highway                object
#  146  tags.maxheight                         object
#  147  tags.tunnel                            object
#  148  tags.tiger:name_direction_suffix       object
#  149  tags.source:surface                    object
#  150  tags.covered                           object
#  151  tags.length                            float64
#  152  tags.source:old_name                   object
#  153  tags.sidewalk:left                     object
#  154  tags.website                           object
#  155  tags.source:maxspeed                   object
#  156  tags.level                             float64
#  157  tags.source:cycleway:right             object
#  158  tags.source:oneway                     object
#  159  tags.source:covered                    object
#  160  tags.smoothness                        object
#  161  tags.mtb:scale                         float64
#  162  tags.embankment                        object
#  163  tags.area                              object
#  164  tags.noname                            object
#  165  tags.tactile_paving                    object
#  166  tags.source:railway                    object
#  167  tags.tiger:zip_right_2                 float64
#  168  tags.wheelchair                        object
#  169  tags.mtb:scale:imba                    float64
#  170  tags.mtb:scale:uphill                  float64
#  171  tags.emergency                         object
#  172  tags.FIXME                             object
#  173  tags.width                             float64
#  174  tags.opened                            float64
#  175  tags.source:hgv                        object
#  176  tags.boundary                          object
#  177  tags.sidewalk:bicycle                  object
#  178  tags.lanes:both_ways                   float64
#  179  tags.destination:ref:lanes:forward     object
#  180  tags.cycleway:surface                  object
#  181  tags.footway:surface                   object
#  182  tags.bus                               object
#  183  city                                   object
# dtypes: float64(24), int64(2), object(158)
# memory usage: 4.0+ MB

# %% [markdown]
# We're going to remove all the highways from our dataset that don't have some sort of designated bicycle passageway on them.

# %%
remove = ['motorway', 'trunk', 'motorway_link','trunk_link']
bike_lanes.drop(bike_lanes.loc[(bike_lanes['tags.highway'].isin(remove)) & (bike_lanes['tags.cycleway'].isnull()) & (bike_lanes['tags.bicycle'] != 'designated')].index, inplace=True)

# %%
remove_columns = ['index','type','tiger', 'bounds', 'source', 'note', 'ref', 'horse', 'maxweight',
                  'layer','name', 'description', 'lanes:']
columns = bike_lanes.columns
for r in remove_columns:
    columns = [c for c in columns if r not in c]

bike_lanes = bike_lanes[columns]

columns = bike_lanes.columns
columns = [c.replace('tags.', '') for c in columns]
bike_lanes.columns = columns

# %%
# get search tearms programmatically
search_terms = ['cycleway:', 'bicycle:']

bike_lanes['cycleway'].fillna(bike_lanes['cycleway:right'], inplace=True)
bike_lanes['cycleway'].fillna(bike_lanes['cycleway:left'], inplace=True)
bike_lanes['cycleway'].fillna(bike_lanes['cycleway:buffer'], inplace=True)

bike_lanes['bicycle'].fillna(bike_lanes['bicycle:designated'], inplace=True)
bike_lanes.drop(columns=['cycleway:right', 'cycleway:left'],
                inplace=True)

# %%
bike_lanes = bike_lanes.loc[:, bike_lanes.isnull().mean() <=.8]
bike_lanes.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2819 entries, 0 to 2849
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     2819 non-null   int64
#  1   type      2819 non-null   object
#  2   id        2819 non-null   int64
#  3   nodes     2819 non-null   object
#  4   geometry  2819 non-null   object
#  5   highway   2815 non-null   object
#  6   lcn       1116 non-null   object
#  7   bicycle   2634 non-null   object
#  8   surface   951 non-null    object
#  9   foot      658 non-null    object
#  10  city      2819 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 264.3+ KB

# %%
bike_lanes.sample(20)
# Out:
#       index type         id  \
# 566     566  way   45116548
# 215     215  way   11805275
# 543     543  way   32149965
# 1785   1785  way  366826460
# 192     192  way   11749562
# 771     771  way  109353387
# 1470   1470  way  340732969
# 161     161  way   11734431
# 1253   1253  way  302256387
# 2285   2285  way  550521575
# 286     286  way   11823255
# 2105   2105  way  454898329
# 1418   1418  way  333009377
# 224     224  way   11808281
# 475     475  way   24931539
# 2024   2024  way  422119993
# 1791   1791  way  366826466
# 2762   2762  way  911052189
# 2299   2299  way  552699172
# 62       62  way   11692000
#
#                                                   nodes  \
# 566   [572065243, 572065248, 572065251, 572065254, 5...
# 215   [105097664, 2715045158, 8006500881, 104931010,...
# 543   [348503522, 3577378231, 3577378224, 3577378200...
# 1785  [3708024661, 3708024665, 3708024677, 370802468...
# 192                   [104667658, 105200935, 105200941]
# 771   [1252101696, 6325959025, 1252102247, 125210211...
# 1470  [360939188, 360939186, 360939184, 360939182, 3...
# 161                   [104667609, 105062455, 105029429]
# 1253  [105075863, 8026959671, 105711578, 2985643145,...
# 2285                           [5317313595, 5317313317]
# 286   [2501737501, 4791807061, 105873289, 2501737880...
# 2105                             [693830504, 105115534]
# 1418   [3401237458, 3401237459, 3401237460, 3401237461]
# 224   [105712972, 105712981, 7914572349, 7914572350,...
# 475   [302450094, 8140356492, 8140356491, 303455144,...
# 2024  [3577378327, 3458513856, 3577378337, 357737833...
# 1791   [3708024645, 3708024647, 3708024651, 3708024656]
# 2762      [105085326, 8256882954, 104929036, 105026849]
# 2299   [2865711344, 5335865824, 5335865825, 1459443115]
# 62        [104491210, 5716528750, 684996262, 684996263]
#
#                                                geometry      highway   lcn  \
# 566   [[40.46761, -79.9281859], [40.466965, -79.9262...    secondary   yes
# 215   [[40.4470707, -79.9472806], [40.4466574, -79.9...  residential   yes
# 543   [[40.4425347, -79.9005591], [40.4424911, -79.9...     cycleway  None
# 1785  [[40.4734153, -80.0209537], [40.4734781, -80.0...      service  None
# 192   [[40.4549439, -79.8876957], [40.4546961, -79.8...      service  None
# 771   [[40.4755834, -79.9568282], [40.4755026, -79.9...      service   yes
# 1470  [[40.4460114, -79.9030646], [40.445948, -79.90...     cycleway   yes
# 161   [[40.4530834, -79.8884226], [40.4528174, -79.8...      service  None
# 1253  [[40.4457173, -79.9563859], [40.4456646, -79.9...     tertiary   yes
# 2285  [[40.4346955, -79.9732857], [40.434484, -79.97...     cycleway   yes
# 286   [[40.4877516, -80.0193205], [40.4878026, -80.0...  residential  None
# 2105  [[40.4586767, -80.0231555], [40.4587857, -80.0...     tertiary   yes
# 1418  [[40.4284278, -79.9493348], [40.4288023, -79.9...      footway   yes
# 224   [[40.4593285, -79.8830573], [40.4601938, -79.8...      service  None
# 475   [[40.4396134, -79.9467751], [40.4396591, -79.9...    secondary   yes
# 2024  [[40.4315054, -79.9130694], [40.4315188, -79.9...         path  None
# 1791  [[40.4732621, -80.0187165], [40.4732825, -80.0...      service  None
# 2762  [[40.4568565, -79.9312267], [40.4567291, -79.9...  residential  None
# 2299  [[40.4532774, -80.012636], [40.4532131, -80.01...      footway  None
# 62    [[40.4485705, -80.0104489], [40.448569, -80.01...      service  None
#
#          bicycle   surface        foot        city
# 566         None   asphalt        None  Pittsburgh
# 215   designated      None        None  Pittsburgh
# 543   designated      None  designated  Pittsburgh
# 1785         yes      None        None  Pittsburgh
# 192          yes      None        None  Pittsburgh
# 771          yes      None        None  Pittsburgh
# 1470  designated      None  designated  Pittsburgh
# 161          yes      None        None  Pittsburgh
# 1253  designated   asphalt        None  Pittsburgh
# 2285  designated  concrete          no  Pittsburgh
# 286          yes   asphalt        None  Pittsburgh
# 2105  designated      None        None  Pittsburgh
# 1418         yes     paved        None  Pittsburgh
# 224          yes      None        None  Pittsburgh
# 475   designated      None        None  Pittsburgh
# 2024         yes      dirt         yes  Pittsburgh
# 1791         yes      None        None  Pittsburgh
# 2762         yes      None        None  Pittsburgh
# 2299         yes      None        None  Pittsburgh
# 62           yes      None        None  Pittsburgh

# %%
for c in bike_lanes.columns:
    if c != 'nodes' and c!='geometry':
        print(f'{c}:')
        values = bike_lanes[c].unique()
        print(f'{values}')
# Out:
# index:
# [   0    1    2 ... 2847 2848 2849]
# type:
# ['way']
# id:
# [ 11651864  11652289  11652864 ... 932572338 934280874 934280875]
# highway:
# ['secondary' 'service' 'path' 'residential' 'unclassified' 'tertiary'
#  'cycleway' 'primary' None 'steps' 'footway' 'secondary_link'
#  'construction' 'tertiary_link' 'pedestrian' 'primary_link' 'track'
#  'busway']
# lcn:
# ['yes' None]
# bicycle:
# [None 'yes' 'designated']
# surface:
# [None 'paved' 'asphalt' 'concrete' 'fine_gravel' 'sett' 'unpaved' 'gravel'
#  'compacted' 'ground' 'dirt' 'paving_stones' 'brick' 'cobblestone' 'earth'
#  'wood']
# foot:
# [None 'yes' 'designated' 'permissive' 'use_sidepath' 'no']
# city:
# ['Pittsburgh']
