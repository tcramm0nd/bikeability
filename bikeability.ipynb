# %% [markdown]
# # Mapping bike lanes in Pittsburgh
# As a cyclist who's primary source of transportation is a bicycle, I wanted to get a better understanding of

# %% [markdown]
# ## Setting up the notebook
# I cheated and wrote a wrapper for accessing Overpass API in a separate file - here is the link to the github gist and, which includes the API class and a quick function to calculate length from the lat/lon coords returned from the API.

# %%
from bikeability import overpass
import pandas as pd
api = overpass.API()

# %%
cycle_query = """(way[highway=cycleway](area.a);way[cycleway=lane](area.a);
                   way[cycleway=asl](area.a);way[cycleway=bike_box](area.a);
                   way[cycleway=crossing](area.a);way[cycleway=opposite_lane](area.a);
                   way[cycleway=opposite_track](area.a);way[cycleway=separate](area.a);
                   way[cycleway=sidepath](area.a);way[cycleway=track](area.a);
                   way[bicycle=designated](area.a);way[bicycle=yes](area.a);
                   way[bicycle_road=yes](area.a);
                   );"""

top_cycling_cities = {'Seattle':237385,
                      'San Francisco': 111968,
                      'Fort Collins': 112524,
                      'Minneapolis': 136712,
                      'Portland': 186579,
                      'Chicago': 122604,
                      'Eugene': 186706,
                      'Madison': 3352040,
                      'New York': 175905,
                      'Cambridge': 1933745
                      }

# %%
results = {}
for city, relation_id in top_cycling_cities.items():
    df = api.get(cycle_query, area_id=relation_id)
    df['city'] = city
    df['length'] = df['geometry'].apply(overpass.length)
    results[city] = df
# Out:
# Retrieved 4358 entries from area: 237385
# 	Time: 11.79 seconds
# 	Attempts: 1
# Retrieved 1780 entries from area: 111968
# 	Time: 4.03 seconds
# 	Attempts: 1
# Retrieved 1482 entries from area: 112524
# 	Time: 3.54 seconds
# 	Attempts: 1
# Retrieved 2043 entries from area: 136712
# 	Time: 4.98 seconds
# 	Attempts: 1
# Retrieved 12167 entries from area: 186579
# 	Time: 11.76 seconds
# 	Attempts: 1
# Retrieved 4410 entries from area: 122604
# 	Time: 9.91 seconds
# 	Attempts: 1
# Retrieved 1761 entries from area: 186706
# 	Time: 3.31 seconds
# 	Attempts: 1
# Retrieved 1561 entries from area: 3352040
# 	Time: 4.55 seconds
# 	Attempts: 1
# Retrieved 6119 entries from area: 175905
# 	Time: 10.92 seconds
# 	Attempts: 1
# Retrieved 661 entries from area: 1933745
# 	Time: 6.08 seconds
# 	Attempts: 1

# %%
raw_data = pd.concat(results.values(), sort=False)
raw_data.reset_index(inplace=True)

# %%
bike_lanes = pd.read_json('2021-04-18_raw_data.json')

# %%
# bike_lanes = raw_data.copy()
bike_lanes.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36351 entries, 0 to 36350
# Data columns (total 518 columns):
#  #    Column                                      Dtype
# ---   ------                                      -----
#  0    index                                       int64
#  1    type                                        object
#  2    id                                          int64
#  3    nodes                                       object
#  4    geometry                                    object
#  5    bounds.minlat                               float64
#  6    bounds.minlon                               float64
#  7    bounds.maxlat                               float64
#  8    bounds.maxlon                               float64
#  9    tags.bicycle                                object
#  10   tags.cycleway:surface                       object
#  11   tags.foot                                   object
#  12   tags.highway                                object
#  13   tags.name                                   object
#  14   tags.segregated                             object
#  15   tags.surface                                object
#  16   tags.bridge                                 object
#  17   tags.layer                                  float64
#  18   tags.lit                                    object
#  19   tags.note                                   object
#  20   tags.railway                                object
#  21   tags.lcn                                    object
#  22   tags.motor_vehicle                          object
#  23   tags.oneway                                 object
#  24   tags.source                                 object
#  25   tags.cycleway:right                         object
#  26   tags.dual_carriageway                       object
#  27   tags.lanes                                  object
#  28   tags.maxspeed                               object
#  29   tags.sidewalk                               object
#  30   tags.cycleway                               object
#  31   tags.wheelchair                             object
#  32   tags.width                                  object
#  33   tags.cycleway:left                          object
#  34   tags.lanes:backward                         float64
#  35   tags.lanes:forward                          object
#  36   tags.parking:lane:both                      object
#  37   tags.turn:lanes:forward                     object
#  38   tags.horse                                  object
#  39   tags.tunnel                                 object
#  40   tags.rcn                                    object
#  41   tags.cycleway:buffer                        object
#  42   tags.parking:condition:right:maxstay        object
#  43   tags.parking:lane:left                      object
#  44   tags.parking:lane:right                     object
#  45   tags.tiger:cfcc                             object
#  46   tags.tiger:county                           object
#  47   tags.tiger:name_base                        object
#  48   tags.tiger:name_direction_suffix            object
#  49   tags.tiger:name_type                        object
#  50   tags.parking:condition:both:maxstay         object
#  51   tags.turn:lanes:backward                    object
#  52   tags.cycleway:left:oneway                   object
#  53   tags.oneway:bicycle                         object
#  54   tags.maxspeed:advisory                      object
#  55   tags.duration                               object
#  56   tags.motorcar                               object
#  57   tags.operator                               object
#  58   tags.route                                  object
#  59   tags.ref                                    object
#  60   tags.tiger:name_direction_prefix            object
#  61   tags.tiger:reviewed                         object
#  62   tags.access                                 object
#  63   tags.service                                object
#  64   tags.ref:fra_crossing                       object
#  65   tags.alt_name                               object
#  66   tags.old_name:1875-1895                     object
#  67   tags.old_name                               object
#  68   tags.name:ja                                object
#  69   tags.name:zh                                object
#  70   tags.trolley_wire                           object
#  71   tags.lanes:both_ways                        object
#  72   tags.turn:lanes:both_ways                   object
#  73   tags.name:etymology:wikidata                object
#  74   tags.change:lanes:backward                  object
#  75   tags.change:lanes:forward                   object
#  76   tags.destination:lanes:forward              object
#  77   tags.destination:ref:lanes:forward          object
#  78   tags.overtaking                             object
#  79   tags.old_ref                                object
#  80   tags.ref:fra_crossing:note                  object
#  81   tags.is_in                                  object
#  82   tags.access:lanes                           object
#  83   tags.bus:lanes                              object
#  84   tags.turn:lanes                             object
#  85   tags.change:lanes                           object
#  86   tags.bus                                    object
#  87   tags.motor_vehicle:conditional              object
#  88   tags.abandoned:railway                      object
#  89   tags.cycleway:both                          object
#  90   tags.centre_turn_lane                       object
#  91   tags.access:lanes:backward                  object
#  92   tags.bus:lanes:backward                     object
#  93   tags.smoothness                             object
#  94   tags.tracktype                              object
#  95   tags.maxheight                              object
#  96   tags.traffic_calming                        object
#  97   tags.access:conditional                     object
#  98   tags.parking:condition:right                object
#  99   tags.parking:lane:right:parallel            object
#  100  tags.tiger:name_base_1                      object
#  101  tags.tiger:name_type_1                      object
#  102  tags.bridge:name                            object
#  103  tags.historic                               object
#  104  tags.ref:nrhp                               float64
#  105  tags.wikidata                               object
#  106  tags.wikimedia_commons                      object
#  107  tags.wikipedia                              object
#  108  tags.abandoned                              object
#  109  tags.vehicle                                object
#  110  tags.destination                            object
#  111  tags.destination:ref                        object
#  112  tags.hov:lanes                              object
#  113  tags.hov:minimum                            float64
#  114  tags.crossing                               object
#  115  tags.footway                                object
#  116  tags.fixme                                  object
#  117  tags.cycleway:right:oneway                  object
#  118  tags.direction                              object
#  119  tags.description                            object
#  120  tags.operator_1                             object
#  121  tags.noname                                 object
#  122  tags.covered                                object
#  123  tags.embedded_rails                         object
#  124  tags.heritage                               object
#  125  tags.maxweight:signed                       object
#  126  tags.website                                object
#  127  tags.man_made                               object
#  128  tags.dual_carriage                          object
#  129  tags.cycleway:both:lane                     object
#  130  tags.heritage:operator                      object
#  131  tags.lcn_ref                                object
#  132  tags.dismount                               object
#  133  tags.area                                   object
#  134  tags.ferry                                  object
#  135  tags.floating                               object
#  136  tags.public_transport                       object
#  137  tags.maxspeed:type                          object
#  138  tags.check_date:surface                     object
#  139  tags.name_1                                 object
#  140  tags.incline                                object
#  141  tags.mtb:scale                              float64
#  142  tags.mtb:scale:imba                         float64
#  143  tags.mtb:scale:uphill                       float64
#  144  tags.handrail:left                          object
#  145  tags.access:lanes:forward                   object
#  146  tags.bus:lanes:forward                      object
#  147  tags.embankment                             object
#  148  tags.step_count                             float64
#  149  tags.bicycle:lanes                          object
#  150  tags.junction                               object
#  151  tags.bicycle_road                           object
#  152  tags.start_date                             object
#  153  tags.except                                 object
#  154  tags.oneway:bus                             object
#  155  tags.cutting                                object
#  156  tags.handrail                               object
#  157  tags.ramp                                   object
#  158  tags.razed                                  object
#  159  tags.history                                object
#  160  tags.sac_scale                              object
#  161  tags.trail_visibility                       object
#  162  tags.divider                                object
#  163  tags.footway:surface                        object
#  164  tags.pedestrian                             object
#  165  tags.bridge:movable                         object
#  166  tags.construction                           object
#  167  tags.tiger:name_direction                   object
#  168  tags.placement                              object
#  169  tags.turn                                   object
#  170  tags.note:lanes                             object
#  171  tags.highway_1                              object
#  172  tags.old_ref_1                              object
#  173  tags.busway:left                            object
#  174  tags.check_date                             object
#  175  tags.opening_date                           object
#  176  tags.ramp:wheelchair                        object
#  177  tags.lanes:bus:backward                     float64
#  178  tags.kerb                                   object
#  179  tags.tactile_paving                         object
#  180  tags.handrail:right                         object
#  181  tags.proposed                               object
#  182  tags.parking:condition:left:maxstay         object
#  183  tags.traffic_signals:sound                  object
#  184  tags.traffic_signals:vibration              object
#  185  tags.emergency                              object
#  186  tags.ramp:bicycle                           object
#  187  tags.amenity                                object
#  188  tags.location                               object
#  189  tags.barrier                                object
#  190  tags.bollard                                object
#  191  tags.material                               object
#  192  tags.motorcycle                             object
#  193  tags.parking:lanes:both                     object
#  194  tags.crossing:island                        object
#  195  tags.busway                                 object
#  196  city                                        object
#  197  length                                      float64
#  198  tags.source:imagery                         object
#  199  tags.change:backward                        object
#  200  tags.change:forward                         object
#  201  tags.destination:backward                   object
#  202  tags.destination:forward                    object
#  203  tags.destination:ref:backward               object
#  204  tags.destination:symbol:forward             object
#  205  tags.turn:forward                           object
#  206  tags.destination:street                     object
#  207  tags.destination:ref:forward                object
#  208  tags.FIXME                                  object
#  209  tags.NHS                                    object
#  210  tags.hgv                                    object
#  211  tags.hgv:state_network                      object
#  212  tags.source:hgv:state_network               object
#  213  tags.source:maxspeed                        object
#  214  tags.official_name                          object
#  215  tags.tiger:separated                        object
#  216  tags.tiger:source                           object
#  217  tags.tiger:tlid                             object
#  218  tags.tiger:zip_right                        object
#  219  tags.junction:ref                           object
#  220  tags.source:destination                     object
#  221  tags.tiger:name_base_2                      object
#  222  tags.hgv:national_network                   object
#  223  tags.source:hgv:national_network            object
#  224  tags.dog                                    object
#  225  tags.placement:backward                     object
#  226  tags.bicycle:designated                     object
#  227  tags.name:pronunciation                     object
#  228  tags.fee                                    object
#  229  tags.network                                object
#  230  tags.payment:cash                           object
#  231  tags.payment:clipper                        object
#  232  tags.payment:prepaid_ticket                 object
#  233  tags.psv                                    object
#  234  tags.hazard:bicycle                         object
#  235  tags.turn:backward                          object
#  236  tags.placement:forward                      object
#  237  tags.created_by                             object
#  238  tags.golf                                   object
#  239  tags.golf_cart                              object
#  240  tags.maxweight                              object
#  241  tags.opening_hours                          object
#  242  tags.level                                  object
#  243  tags.taxi                                   object
#  244  tags.old_name:pronunciation                 object
#  245  tags.oneway:psv                             object
#  246  tags.contact:phone                          object
#  247  tags.diet:halal                             object
#  248  tags.destination:lanes                      object
#  249  tags.destination:ref:lanes                  object
#  250  tags.truck                                  object
#  251  tags.bridge:structure                       object
#  252  tags.note:highway                           object
#  253  tags.note:lcn                               object
#  254  tags.bicycle:lanes:backward                 object
#  255  tags.indoor                                 object
#  256  tags.delivery                               object
#  257  tags.stroller                               object
#  258  tags.tiger:upload_uuid                      object
#  259  tags.loc_name                               object
#  260  tags.parking:both                           object
#  261  tags.tiger:name_direction_prefix_1          object
#  262  tags.cycleway:both:buffer                   object
#  263  tags.CDOT_route                             object
#  264  tags.name_2                                 object
#  265  tags.alt_name_1                             object
#  266  tags.cycleway:left:buffer                   object
#  267  tags.cycleway:right:buffer                  object
#  268  tags.cycleway:both:width                    object
#  269  tags.parking:condition:both                 object
#  270  tags.traffic_signals:direction              object
#  271  tags.cycleway_1                             object
#  272  tags.tiger:name_direction_prefix_2          object
#  273  tags.tiger:name_type_2                      object
#  274  tags.cycleway:lane:buffer                   object
#  275  tags.parking:right                          object
#  276  tags.highway_2                              object
#  277  tags.electric_bicycle                       object
#  278  tags.maxspeed:backward                      object
#  279  tags.maxspeed:forward                       object
#  280  tags.tiger:zip_left                         object
#  281  tags.tiger:zip_left_1                       float64
#  282  tags.tiger:zip_right_1                      float64
#  283  tags.cyclestreet                            object
#  284  tags.maxweightrating:hgv                    object
#  285  tags.cycleway:lane                          object
#  286  tags.cycleway:track                         object
#  287  tags.tiger:zip_left_2                       float64
#  288  tags.tiger:zip_left_3                       float64
#  289  tags.tiger:zip_right_3                      float64
#  290  tags.tiger:zip_left_4                       float64
#  291  tags.lane_markings                          object
#  292  tags.tiger:name_direction_suffix_1          object
#  293  tags.cyclerating                            float64
#  294  tags.surface:material                       object
#  295  tags.tiger:zip_right_2                      float64
#  296  tags.bikeway:type                           object
#  297  tags.ski                                    object
#  298  tags.snowmobile                             object
#  299  tags.loppet                                 object
#  300  tags.mtb:access                             object
#  301  tags.cycleway:right:track                   object
#  302  tags.old_name_1                             object
#  303  tags.oneway:foot                            object
#  304  tags.RLIS:systemname                        object
#  305  tags.est_width                              object
#  306  tags.source:bicycle                         object
#  307  tags.RLIS:bicycle                           object
#  308  tags.lanes:bus                              float64
#  309  tags.destination:ref:to                     object
#  310  tags.destination:symbol                     object
#  311  tags.hazmat                                 object
#  312  tags.description_2                          object
#  313  tags.parking:lane:both:parallel             object
#  314  tags.maxspeed:variable                      object
#  315  tags.parking:condition:left                 object
#  316  tags.source:cycleway                        object
#  317  tags.change:lanes:bus                       object
#  318  tags.short_name                             object
#  319  tags.destination:ref:lanes:backward         object
#  320  tags.destination:ref:to:lanes:backward      object
#  321  tags.destination:symbol:backward            object
#  322  tags.turn:both_ways                         object
#  323  tags.change:both_ways                       object
#  324  tags.mtb                                    object
#  325  tags.priority_road                          object
#  326  tags.reg_name                               object
#  327  tags.unsigned_ref                           object
#  328  tags.name:etymology                         object
#  329  tags.cycleway:backward                      object
#  330  tags.hgv:backward                           object
#  331  tags.description_1                          object
#  332  tags.lanes:psv                              float64
#  333  tags.psv:lanes                              object
#  334  tags.cycleway:source                        object
#  335  tags.bridge:ref                             object
#  336  tags.path                                   object
#  337  tags.name:proposed                          object
#  338  tags.busway:right                           object
#  339  tags.RLIS:trailid                           float64
#  340  tags.motor_vehicle:lanes                    object
#  341  tags.destination:lanes:backward             object
#  342  tags.destination:street:forward             object
#  343  tags.destination:street:lanes:backward      object
#  344  tags.destination:street:backward            object
#  345  tags.lanes:bus:forward                      float64
#  346  tags.maxspeed:hgv                           object
#  347  tags.maxaxleload                            object
#  348  tags.phone                                  object
#  349  tags.noexit                                 object
#  350  tags.construction:date_off                  object
#  351  tags.source:shared_lane                     object
#  352  tags.note:cycleway                          object
#  353  tags.hgv:forward                            object
#  354  tags.destination:symbol:lanes:backward      object
#  355  tags.destination:street:lanes               object
#  356  tags.destination:symbol:lanes               object
#  357  tags.cycleway:right:lane                    object
#  358  tags.mtb:description                        object
#  359  tags.sidewalk:both:bicycle                  object
#  360  tags.note:shared_lane                       object
#  361  tags.destination:symbol:lanes:forward       object
#  362  tags.shoulder                               object
#  363  tags.cycleway:left:lane                     object
#  364  tags.source:name                            object
#  365  tags.url                                    object
#  366  tags.disused                                object
#  367  tags.surface:bicycle                        object
#  368  tags.surface:motor_vehicle                  object
#  369  tags.source:lanes                           object
#  370  tags.sidewalk:left:surface                  object
#  371  tags.trail_name                             object
#  372  tags.maxspeed:conditional                   object
#  373  tags.tram                                   object
#  374  tags.bmx                                    object
#  375  tags.skateboard                             object
#  376  tags.leisure                                object
#  377  tags.playground                             object
#  378  tags.destination:street:lanes:forward       object
#  379  tags.sport                                  object
#  380  tags.sidewalk:right                         object
#  381  tags.bicycle:backward                       object
#  382  tags.bicycle:forward                        object
#  383  tags.access:lanes:both_ways                 object
#  384  tags.sidewalk:both:surface                  object
#  385  tags.paved                                  object
#  386  tags.parking:lane:left:capacity             float64
#  387  tags.parking:lane:left:marked               object
#  388  tags.foot:left                              object
#  389  tags.foot:right                             object
#  390  tags.lanes:both                             float64
#  391  tags.sidewalk:right:surface                 object
#  392  tags.cycleway:lanes                         object
#  393  tags.vehicle:lanes                          object
#  394  tags.hgv:lanes                              object
#  395  tags.footway:right                          object
#  396  tags.change                                 object
#  397  tags.loc_ref                                object
#  398  tags.parking:lane:left:parallel             object
#  399  tags.marked_trail                           object
#  400  tags.postal_code                            float64
#  401  tags.old_railway_operator                   object
#  402  tags.bridge_number                          float64
#  403  tags.old_name_2                             object
#  404  tags.tiger:name_base_3                      object
#  405  tags.tiger:name_direction_prefix_3          object
#  406  tags.tiger:name_type_3                      object
#  407  tags.colour                                 object
#  408  tags.owner                                  object
#  409  tags.ownership                              object
#  410  tags.note:old_railway_operator              object
#  411  tags.abandoned:name                         object
#  412  tags.abandoned:operator                     object
#  413  tags.electrified                            object
#  414  tags.gauge                                  float64
#  415  tags.uic_shuttle_route                      object
#  416  tags.building                               object
#  417  tags.building:levels                        float64
#  418  tags.crossing_ref                           object
#  419  tags.gnis:county_id                         float64
#  420  tags.gnis:created                           object
#  421  tags.gnis:feature_id                        float64
#  422  tags.gnis:state_id                          float64
#  423  tags.bicycle:lanes:forward                  object
#  424  tags.informal                               object
#  425  tags.destination:to                         object
#  426  tags.name:etymology:wikipedia               object
#  427  tags.source:bridge:name                     object
#  428  tags.comment                                object
#  429  tags.designation                            object
#  430  tags.source:name:etymology                  object
#  431  tags.road_marking                           object
#  432  tags.source:position                        object
#  433  tags.motor_vehicle:backward                 object
#  434  tags.cycleway:left:width                    object
#  435  tags.cycleway:right:width                   object
#  436  tags.cycleway:buffer:left                   object
#  437  tags.parking:lane                           object
#  438  tags.icn                                    object
#  439  tags.tiger:zip                              float64
#  440  tags.flashing_lights                        object
#  441  tags.toll                                   object
#  442  tags.toll:bicycle                           object
#  443  tags.parking:condition:right:time_interval  object
#  444  tags.maxheight:backward                     object
#  445  tags.maxheight:forward                      object
#  446  tags.maxspeed:advisory:backward             object
#  447  tags.inline_skates                          object
#  448  tags.rcn_ref                                float64
#  449  tags.tiger:name_base_4                      object
#  450  tags.old_name:1811-1883                     object
#  451  tags.name:ar                                object
#  452  tags.name:en                                object
#  453  tags.parking:lane:both:width                object
#  454  tags.oneway:horse                           object
#  455  tags.source:hgv                             object
#  456  tags.source_ref                             object
#  457  tags.parking:lane:width                     object
#  458  tags.type                                   object
#  459  tags.aerialway                              object
#  460  tags.aerialway:capacity                     float64
#  461  tags.aerialway:duration                     float64
#  462  tags.aerialway:occupancy                    float64
#  463  tags.seamark:type                           object
#  464  tags.highway:historical                     object
#  465  tags.name:ru                                object
#  466  tags.name1                                  object
#  467  tags.parking:condition:left:time_interval   object
#  468  tags.name:left                              object
#  469  tags.name:right                             object
#  470  tags.name:el                                object
#  471  tags.source:geometry                        object
#  472  tags.cycle                                  object
#  473  tags.lanes:bus:conditional                  object
#  474  tags.parking:lane:left:width                object
#  475  tags.parking:lane:right:width               object
#  476  tags.motor_vehicle:forward:conditional      object
#  477  tags.seg                                    object
#  478  tags.old_name:1811-1879                     object
#  479  tags.old_name:1954-1957                     object
#  480  tags.highway:lanes                          object
#  481  tags.bicycle:conditional                    object
#  482  tags.oneway:motor_vehicle                   object
#  483  tags.ford                                   object
#  484  tags.source:oneway                          object
#  485  tags.tiger:zip_right_4                      float64
#  486  tags.name:be                                object
#  487  tags.area:highway                           object
#  488  tags.highway:category:pl                    object
#  489  tags.parking:condition:right:default        object
#  490  tags.motor_vehicle:lanes:backward           object
#  491  tags.name:ko                                object
#  492  tags.source:url                             object
#  493  tags.cycleway:oneway                        float64
#  494  tags.old_name:1883-1928                     object
#  495  tags.proposed:cycleway:left                 object
#  496  tags.turn:bicycle:lanes                     object
#  497  tags.parking:condition:both:default         object
#  498  tags.foot:conditional                       object
#  499  tags.separated                              object
#  500  tags.from                                   object
#  501  tags.to                                     object
#  502  tags.maxheight:physical:backward            object
#  503  tags.maxheight:physical:forward             object
#  504  tags.maxheight:note                         object
#  505  tags.FIXME_1                                object
#  506  tags.attribution                            object
#  507  tags.condition                              object
#  508  tags.massgis:ref                            object
#  509  tags.massgis:way_id                         object
#  510  tags.name:mk                                object
#  511  tags.crossing:signals                       object
#  512  tags.cycleway:lanes:backward                object
#  513  tags.vehicle:lanes:backward                 object
#  514  tags.tourism                                object
#  515  tags.fishing                                object
#  516  tags.massdep:license                        float64
#  517  tags.height                                 float64
# dtypes: float64(44), int64(2), object(472)
# memory usage: 143.9+ MB

# %% [markdown]
# We're going to remove all the highways from our dataset that don't have some sort of designated bicycle passageway on them.

# %%
remove = ['motorway', 'trunk', 'motorway_link','trunk_link']
bike_lanes.drop(bike_lanes.loc[(bike_lanes['tags.highway'].isin(remove)) & (bike_lanes['tags.cycleway'].isnull()) & (bike_lanes['tags.bicycle'] != 'designated')].index, inplace=True)

# %%
remove_columns = ['tiger', 'bounds', 'source', 'note', 'ref', 'horse', 'maxweight',
                  'layer','name', 'description', 'lanes:']
columns = bike_lanes.columns
for r in remove_columns:
    columns = [c for c in columns if r not in c]

bike_lanes = bike_lanes[columns]

columns = bike_lanes.columns
columns = [c.replace('tags.', '') for c in columns]
bike_lanes.columns = columns

# %%
search_terms = ['cycleway:', 'bicycle:']

bike_lanes['cycleway'].fillna(bike_lanes['cycleway:right'], inplace=True)
bike_lanes['cycleway'].fillna(bike_lanes['cycleway:left'], inplace=True)
bike_lanes['cycleway'].fillna(bike_lanes['cycleway:buffer'], inplace=True)

bike_lanes['bicycle'].fillna(bike_lanes['bicycle:designated'], inplace=True)
bike_lanes.drop(columns=['cycleway:right', 'cycleway:left', 'cycleway:buffer', 'bicycle:designated'],
                inplace=True)
# Out:
# /home/tim/Projects/bikeability/.venv/lib/python3.8/site-packages/pandas/core/series.py:4460: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
bike_lanes = bike_lanes.loc[:, bike_lanes.isnull().mean() <=.99]

# %%
bike_lanes.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35804 entries, 0 to 36350
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 35804 non-null  int64
#  1   type                  35804 non-null  object
#  2   id                    35804 non-null  int64
#  3   nodes                 35804 non-null  object
#  4   geometry              35804 non-null  object
#  5   bicycle               28709 non-null  object
#  6   foot                  8392 non-null   object
#  7   highway               35727 non-null  object
#  8   segregated            2915 non-null   object
#  9   surface               13898 non-null  object
#  10  bridge                1687 non-null   object
#  11  lit                   2331 non-null   object
#  12  lcn                   729 non-null    object
#  13  motor_vehicle         2333 non-null   object
#  14  oneway                10660 non-null  object
#  15  lanes                 14818 non-null  object
#  16  maxspeed              15465 non-null  object
#  17  sidewalk              11444 non-null  object
#  18  cycleway              12735 non-null  object
#  19  width                 1150 non-null   object
#  20  parking:lane:both     621 non-null    object
#  21  access                1564 non-null   object
#  22  trolley_wire          786 non-null    object
#  23  turn:lanes            1089 non-null   object
#  24  crossing              701 non-null    object
#  25  footway               1147 non-null   object
#  26  city                  35804 non-null  object
#  27  length                35804 non-null  float64
#  28  NHS                   1085 non-null   object
#  29  hgv                   2635 non-null   object
#  30  hgv:national_network  620 non-null    object
#  31  network               401 non-null    object
#  32  est_width             1506 non-null   object
#  33  RLIS:bicycle          1208 non-null   object
# dtypes: float64(1), int64(2), object(31)
# memory usage: 9.6+ MB

# %%
b_tag = bike_lanes[(bike_lanes['highway'] != 'cycleway') & (bike_lanes['cycleway'].isna())]
b_tag.notna().mean()
# Out:
# index                   1.000000
# type                    1.000000
# id                      1.000000
# nodes                   1.000000
# geometry                1.000000
# bicycle                 1.000000
# foot                    0.249240
# highway                 0.995967
# segregated              0.072877
# surface                 0.417813
# bridge                  0.039892
# lit                     0.074535
# lcn                     0.014365
# motor_vehicle           0.052821
# oneway                  0.287253
# lanes                   0.370794
# maxspeed                0.407260
# sidewalk                0.345875
# cycleway                0.000000
# width                   0.033704
# parking:lane:both       0.009780
# access                  0.034532
# trolley_wire            0.014531
# turn:lanes              0.035914
# crossing                0.019946
# footway                 0.060224
# city                    1.000000
# length                  1.000000
# NHS                     0.038566
# hgv                     0.089950
# hgv:national_network    0.022156
# network                 0.018067
# est_width               0.076358
# RLIS:bicycle            0.059285
# dtype: float64

# %%
b_tag['foot'].unique()
# Out:
# array([nan, 'yes', 'designated', 'official', 'no', 'permissive',
#        'use_sidepath', 'discouraged', 'destination'], dtype=object)

# %%
b_tag['surface'].unique()
# Out:
# array(['concrete', nan, 'asphalt', 'paved', 'gravel', 'paving_stones',
#        'ground', 'compacted', 'fine_gravel', 'concrete;metal', 'wood',
#        'metal', 'dirt', 'unpaved', 'metal_grid', 'concrete:plates',
#        'sand', 'tile', 'grass', 'brick', 'pebblestone', 'grass_paver',
#        'sett', 'open_grate', 'cobblestone', 'dirt,gravel',
#        'paved_concrete', 'paved;wood', 'cement', 'earth', 'Sett'],
#       dtype=object)

# %%
b_tag['surface'].unique()
# Out:
# array(['concrete', nan, 'asphalt', 'paved', 'gravel', 'paving_stones',
#        'ground', 'compacted', 'fine_gravel', 'concrete;metal', 'wood',
#        'metal', 'dirt', 'unpaved', 'metal_grid', 'concrete:plates',
#        'sand', 'tile', 'grass', 'brick', 'pebblestone', 'grass_paver',
#        'sett', 'open_grate', 'cobblestone', 'dirt,gravel',
#        'paved_concrete', 'paved;wood', 'cement', 'earth', 'Sett'],
#       dtype=object)

# %%
raw_data.to_json('raw_data.json', orient='columns')

# %%
to assign values based on conditionals
df['c1'].loc[df['c1'] == 'Value'] = 10
# Out:
#   File "<ipython-input-13-19816482218a>", line 1
#     to assign values based on conditionals
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Features to include outside of OSM
# - cycling deaths per year
# - cycling accidents per year
